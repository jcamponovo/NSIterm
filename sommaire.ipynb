# %%
from IPython.display import Javascript
from ipywidgets import FileUpload, Button, HBox, Layout, Dropdown, VBox,Label, Accordion,HTML, Image
import os
timeout = 120 # minutes
Javascript("""let timerId = setInterval(() => IPython.notebook.kernel.execute("a=1"), 300000);
setTimeout(() => { clearInterval(timerId); alert('fin de cession'); },"""+ str(timeout*1000*60)+")")

# %%
Javascript("""Jupyter.actions.call('jupyter-notebook:hide-header')""")

# %%
Javascript("""Jupyter.actions.call('jupyter-notebook:hide-toolbar')""")

# %%
display(HTML("""<h1 style="text-align:center; width:100%;"> Cours de terminale NSI 2020/2021 </h1>"""))
# Out:
# HTML(value='<h1 style="text-align:center; width:100%;"> Cours de terminale NSI 2020/2021 </h1>')

# %%
def changeLinks(code):
    liens = []
    if code == 0 or code =="Original":
        liens.append("""<ul><li><a href="../notebooks/Cours_00/cours_00.ipynb">Cours_00</a></li>
<ul><li><a href="../notebooks/Cours_00/TD_00_1.ipynb">TD_00_1</a></li></ul></ul>""")
        
        liens.append("""<ul>
    <li><a href="../notebooks/Cours_01/cours_01_1.ipynb">I. Le tableau</a></li>
    <li><a href="../notebooks/Cours_01/cours_01_2.ipynb">II. La Pile</a></li>
    <ul>
        <li><a href="../notebooks/Cours_01/TD_01_1.ipynb">TD_01_1 - Utilisation des piles</a> et <a href="../notebooks/Cours_01/TD_01_1_cor.ipynb">correction</a></li>
    </ul>
    <li><a href="../notebooks/Cours_01/cours_01_3.ipynb">III. La File</a></li>
    <li><a href="../notebooks/Cours_01/cours_01_4.ipynb">IV. La Liste chaînée</a></li>
    <ul>
        <li><a href="../notebooks/Cours_01/TD_01_2.ipynb">TD_01_2 - Autres structures de données</a></li>
        <li><a href="../notebooks/Cours_01/TD_01_3.ipynb">TD_01_3 - Implémentation de structures de données par programmation orientée objet</a></li>
    </ul>
    <li><a href="../notebooks/Cours_01/cours_01_5.ipynb">V. Le Dictionnaire</a></li>
</ul>""")
        
        liens.append("""<ul>
                    <li><a href="../notebooks/Cours_02/cours_02_1.ipynb">I. Définitions</a></li>
                    <li><a href="../notebooks/Cours_02/cours_02_2.ipynb">II. Pile d'appel</a></li>
                    <ul>
                        <li><a href="../notebooks/Cours_02/TD_02_1.ipynb">TD_02_1 - Fonctions récursives et fractales</a></li>
                    </ul>
                    <li><a href="../notebooks/Cours_02/cours_02_3.ipynb">III. Limites</a></li>
                    <ul>
                        <li><a href="../notebooks/Cours_02/TD_02_2.ipynb">TD_02_2 - Ecrire des fonctions récursives</a></li>
                    </ul>
                </ul>""")
        
        liens.append("""<ul><li><a href="../notebooks/Cours_03/cours_03_1.ipynb">I. César</a></li>
<li><a href="../notebooks/Cours_03/cours_03_2.ipynb">II. Vigenère</a></li>
<li><a href="../notebooks/Cours_03/cours_03_3.ipynb">III. Chiffrement à clé publique</a></li>
<ul><li><a href="../notebooks/Cours_03/TD_03_1.ipynb">TD_03_1 - Nombres premiers</a></li>
<li><a href="../notebooks/Cours_03/TD_03_2.ipynb">TD_03_2 - RSA</a></li></ul></ul>""")
    
    else:
        code = int(code)
        liens.append("""<ul><li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_00.ipynb">Cours_00</a></li>
<ul><li><a href="../notebooks/personnalisation_2020/{0:02d}/TD_00_1.ipynb">TD_00_1</a></li></ul></ul>""".format(code))
        
        liens.append("""<ul>
    <li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_01_1.ipynb">I. Le tableau</a></li>
    <li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_01_2.ipynb">II. La Pile</a></li>
    <ul>
        <li><a href="../notebooks/personnalisation_2020/{0:02d}/TD_01_1.ipynb">TD_01_1 - Utilisation des piles</a> et <a href="../notebooks/Cours_01/TD_01_1_cor.ipynb">correction</a></li>
    </ul>
    <li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_01_3.ipynb">III. La File</a></li>
    <li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_01_4.ipynb">IV. La Liste chaînée</a></li>
    <ul>
        <li><a href="../notebooks/personnalisation_2020/{0:02d}/TD_01_2.ipynb">TD_01_2 - Autres structures de données</a></li>
        <li><a href="../notebooks/personnalisation_2020/{0:02d}/TD_01_3.ipynb">TD_01_3 - Implémentation de structures de données par programmation orientée objet</a></li>
    </ul>
    <li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_01_5.ipynb">V. Le Dictionnaire</a></li>
</ul>""".format(code))
        
        liens.append("""<ul>
                    <li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_02_1.ipynb">I. Définitions</a></li>
                    <li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_02_2.ipynb">II. Pile d'appel</a></li>
                    <ul>
                        <li><a href="../notebooks/personnalisation_2020/{0:02d}/TD_02_1.ipynb">TD_02_1 - Fonctions récursives et fractales</a></li>
                    </ul>
                    <li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_02_3.ipynb">III. Limites</a></li>
                    <ul>
                        <li><a href="../notebooks/personnalisation_2020/{0:02d}/TD_02_2.ipynb">TD_02_2 - Ecrire des fonctions récursives</a></li>
                    </ul>
                </ul>""".format(code))
        
        liens.append("""<ul><li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_03_1.ipynb">I. César</a></li>
<li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_03_2.ipynb">II. Vigenère</a></li>
<li><a href="../notebooks/personnalisation_2020/{0:02d}/cours_03_3.ipynb">III. Chiffrement à clé publique</a></li>
<ul><li><a href="../notebooks/personnalisation_2020/{0:02d}/TD_03_1.ipynb">TD_03_1 - Nombres premiers</a></li>
<li><a href="../notebooks/personnalisation_2020/{0:02d}/TD_03_2.ipynb">TD_03_2 - RSA</a></li></ul></ul>""".format(code))
    return liens

liens = changeLinks(0)

accordion = Accordion(children=[HBox([Image(
    value=open("img/mise_en_route.jpg", "rb").read(),
    format='jpg',
    width=400,
    height=400,
),HTML(liens[0])]), HBox([Image(
    value=open("img/hashtable.png", "rb").read(),
    format='png',
    width=400,
    height=400,
),HTML(liens[1])]), HBox([HTML(value='<img src="https://upload.wikimedia.org/wikipedia/commons/0/07/Tower_of_Hanoi.jpeg" width="400px">'),
                   HTML(liens[2])]), HBox([Image(
    value=open("img/enigma.jpg", "rb").read(),
    format='jpg',
    width=400,
    height=400,
),HTML(liens[3])])], selected_index=None)

accordion.set_title(0, 'Cours 00 - Mise en route')
accordion.set_title(1, 'Cours 01 - Structures de données')
accordion.set_title(2, 'Cours 02 - Récursivité')
accordion.set_title(3, 'Cours 03 - Cryptographie')

def change2(b):
    global liens,bou4,accordion
    if bou4.value == "Original":
        liens = changeLinks(0)
    else:
        liens = changeLinks(bou4.value)
    for i in range(len(accordion.children)):
        accordion.children[i].children[1].value=liens[i]
        
    

liste_e = [val for val in os.listdir("./personnalisation_2020/") if len(val)==2 and val[0]!="."]
liste_e.sort()
liste_e = ["Original"] + liste_e
    
bou4 = Dropdown(
    options=liste_e,
    value="Original",
    description='Cours',
    disabled=False,
)

bou4.observe(change2,"value")
display(bou4)
display(accordion)
# Out:
# Dropdown(description='Cours', options=('Original', '01', '02', '03', '04', '05', '06', '07', '08', '09', '10',…
# Accordion(children=(HBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x0…
