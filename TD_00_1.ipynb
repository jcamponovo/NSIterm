# %%
# Permet de tout executer au lancement du notebook + conserver le notebook actif pendant 2h
from IPython.display import Javascript
from masquer import *
Javascript("""
function repeter(){
IPython.notebook.kernel.execute("a=1");
}
// execute a = 1 en python toutes les 8 minutes pendant 2h
let timerId = setInterval(() => repeter(), 4800);
setTimeout(() => { clearInterval(timerId); alert('fin de cession'); }, 7200000);

// Supprimer la taille limite pour la sortie d'une cellule
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
};
IPython.notebook.kernel.execute("url = '" + window.location + "'");

// Exécuter toutes les cellule du notebook
    require(
        ['base/js/namespace', 'jquery'], 
        function(jupyter, $) {
            
                
                jupyter.actions.call('jupyter-notebook:run-all-cells-below');
                jupyter.actions.call('jupyter-notebook:save-notebook');
                Jupyter.actions.call('jupyter-notebook:hide-header')

        }
    );""")

# %% [markdown]
# # <span style="color:red;"><center>TD - Les bases de Python </center></span>

# %% [markdown]
# ## I. Le traditionnel "Hello World"

# %% [markdown]
# Hello world (traduit littéralement en français par « Bonjour le monde ») sont les mots traditionnellement écrits par un programme informatique simple dont le but est de faire la démonstration rapide de son exécution sans erreur. (*Wikipédia*)
#
# * ``print()`` est une fonction qui permet l’affichage de texte dans la console.
# * ``print("Hello World")`` permet l’affichage dans la console de la **chaîne de caractères** : *Hello World*

# %% [markdown]
# **Q1. Ecrire et éxecuter le code python pour faire afficher Hello World.**

# %%
# Question 1

# %% [markdown]
# Une chaîne de caractères s’écrit entre guillemets (" ") ou entre quotes (' '), les lignes suivantes donnent donc la même chose :
# > ``` python
# print("Ceci est une chaîne de caractères")
# print('Ceci est une chaîne de caractères')
# ```

# %% [markdown]
# **Q2. Tester les deux instructions ci-dessus avec la chaine de caractère :** `C'est la rentrée`.

# %%
# Question 2

# %% [markdown]
# ## II. Les variables
#
# Une **variable** comme son nom l’indique c’est variable...
# Par exemple, le code suivant stocke la phrase précédente dans la variable *maphrase* et
# ensuite l’affiche :
# > ``` python
# maphrase = 'Ceci est une chaîne de caractères.'
# print(maphrase)```
#
# L’opérateur **=** permet **l’affectation** d’une valeur à une variable.

# %% [markdown]
# **Q3. Que se passe t-il si on inverse les deux lignes de codes? Et pourquoi?**

# %%
# Questions 3

# %% [markdown]
# *Attention : Si vous exécutez d'abord les 2 lignes de code dans le bon ordre, puis dans le mauvais, vous ne remarquerez rien de particulier.
# Il faut alors relancer le noyau python avec le bouton Redémarrer de la barre d'outils (voir image ci-dessous). Essayez de comprendre pourquoi.*  ![](img/fleche_tourne.png)

# %% [markdown]
# Le contenu d'une variable peut être modifié à tout moment.
# ***
# **Ajouter une cellule de code pour tester le code ci-dessous :**
# > ``` python
# maphrase = 'Ceci est une chaîne de caractères'
# print(maphrase)
# maphrase = 'Ceci est une autre chaîne de caractères'
# print(maphrase)
# maphrase = 23
# print(maphrase)
# ```

# %% [markdown]
# ## III. Les types simples
# En informatique on manipule des **données**, elles peuvent être de **types simples** (nombres, mots, booléens(Vrai ou Faux)) ou comme nous le verrons plus tard de **types construits** (listes, tuples, dictionnaires) et enfin **structurées** (tableaux, base de données).
# - **Les nombres** :
#     - Les **entiers** (positifs ou négatifs) de type `int`, pour integer.
#     - Les **nombres à virgule** de type `float`, pour nombre à virgule flottante.
# *_Remarque_ : Du fait de la limitation en mémoire, en informatique tous les réels sont des décimaux, il ne peut pas y avoir une infinité de chiffres après la virgule.*

# %% [markdown]
# - **Les chaînes de caractères** : Le type d’une chaîne de caractère est `str`, pour String.
# - Les **booléens** : Le type d’un booléen est `bool`, pour boolean. Un booléen ne peut avoir que deux valeurs : `True` ou `False`.
#
#
# **IMPORTANT :** En Python, le typage d’une variable est *implicite* : c’est à dire que le type d’une variable n'a pas à être défini dès le départ et s'adapte à ce que la variable contient.
#
#
# La fonction `type` permet de connaître le type d'une variable existante.

# %% [markdown]
# **Q4. Tester le code suivant dans lequel on a affecté des valeurs à des variables puis on affiche leur type.**
# > ``` python
# n=12
# x=1.23
# maphrase='Ceci est une chaîne de caractères'
# test=True
# print(type(n))
# print(type(x))
# print(type(maphrase))
# print(type(test))
# ```

# %%
# Question 4

# %% [markdown]
# La fonction `input()` permet à l’utilisateur de rentrer une **donnée au clavier** pour une utilisation ultérieure dans le programme. Le texte tapé par l’utilisateur est toujours de type `str` mais il est possible d'en modifier le type à l'aide des fonctions `int()` ou `float()` par exemple.

# %% [markdown]
# **Q5. Comparer l'exécution des deux programmes suivants, quelle est la différence ?**
# > ```python
# n=input('Entrer un nombre :')
# print(n, type(n))
# ```
# > ```python
# n=int(input('Entrer un nombre :'))
# print(n, type(n))
# ```

# %%
# Question 5

# %% [markdown]
# ## IV. Les opérations de base
# Les différentes opérations possibles dépendent du type de données manipulées.

# %% [markdown]
# ### IV.1 Les opérateurs arithmétiques sur les nombres
# - L'addition : `+`
# - La soustraction : `-`
# - La multiplication : `*`
# - La division : `/`
# - La division entière : `//`
# - Le reste de la division entière : `%`
# - La puissance : `**`

# %% [markdown]
# Les autres fonctions mathématiques standard telles que `sqrt` (pour la racine carrée),  `sin`, `cos`, `exp`, ... nécessitent **d'importer la bibliothèque `math`** en ajoutant l'instruction `from math import *` au début du programme.

# %% [markdown]
# **Q6. On considère les variables $a = 51$, $b = 7$, $c = 21.4$, calculer et faire afficher les résultats des opérations suivantes : $a + b$, $b - c$, $a\, /\, b$, $a \times b$, $a\, //\, b$, $c\, \%\, b$, $b^4$ et $\sqrt{\frac{a + c}{b^2}}$.**

# %%
# Question 6

# %% [markdown]
# *Remarques :*
# * On rappelle qu'en python, le séparateur décimal est un "." et non une ",".
# * Faites afficher le type de $a$, de $b$ puis de $a\,/\,b$. Vous verrez alors que le résultat d'une opération n'est pas forcément du même type que les données de départ.
# * Si vous calculez $b-c$ à la main, trouvez-vous le même résultat qu'en python ? Pourquoi ?

# %% [markdown]
# ### IV.2 Les opérations sur les chaînes de caractères
# L'opération qui consiste à assembler bout à bout 2 chaînes de caractère s'appelle une **concaténation**. Elle se fait simplement avec l'opérateur `+`, comme une addition.

# %% [markdown]
# **Q7. Corriger les lignes de code suivantes pour qu'elles affichent `Ceci est une chaîne de caractères.`**
# > ``` python
# ch1='Ceci est une'
# ch2='chaîne de caractères.'
# print(ch1+ch2)
# ```

# %%
# Question 7

# %% [markdown]
# *Question subsidiaire :* D'après vous, que produit l'instruction `print('Hello'*3)`? Faire le test après y avoir bièvement réfléchi.

# %% [markdown]
# Une chaîne de caractères est dite **itérable**, cela signifie que l’on peut accéder à chacun des caractères grâce à son indice : **le premier caracrère porte l'indice 0**, le deuxième l'indice 1, ...
#
# Si la variable `maphrase` est une chaîne de caractère, on accède à son caractère d'indice i (i est un entier) grâce à l'expression `maphrase[i]`.
#
# La fonction `len()` renvoie la **longueur d’une chaîne de caractères**, c'est-à-dire le nombre de caractères qui la compose.

# %% [markdown]
# **Q8. Soit la chaîne de caractères 'Ceci est une chaîne de caractère' :**
# - Affecter cette chaîne de caractère dans la variable `maphrase`.
# - Faire afficher la longueur de cette chaîne de caractère.
# - Faire afficher le dernier caractère de `maphrase` puis son 4ème caractère (c'est un "i" !).

# %%
# Question 8

# %% [markdown]
# On peut aussi accèder directement à une **sous-chaîne** d'une chaîne de caractère qui serait, par exemple, stockée dans la variable `maphrase` :
# - l'expression `maphrase[p:q]` correspond à la sous-chaîne allant de l'indice p à q-1.
# - l'expression `maphrase[p:]` correspond à la sous-chaîne depuis l’indice p jusqu’à la fin de la chaîne.
# - l'expression `maphrase[:q]` pour la sous-chaîne depuis l’indice 0 jusqu’à l’indice q - 1 de la chaîne.

# %% [markdown]
# **Q9. En utilisant les 3 expressions précédentes, faire afficher les mots 'Ceci', 'chaîne' et 'caractères.' de la chaîne 'Ceci est une chaîne de caractères.'.**

# %%
# Question 9

# %% [markdown]
# ## V. Les instructions conditionnelles
# Une instruction conditionnelle est une instruction que ne s'éxecute que si une certaine condition est réalisée. Cette condition s'écrit le plus souvent sous la forme d'un **test de comparaison**. En général, l'instruction conditionnelle n'est exécutée que si le résultat de ce test est vrai.

# %% [markdown]
# ### V.1 Les opérateurs de comparaison
#  Soient x et y deux **variables numériques**, alors on peut tester :
#  - leur **égalité** avec l'opérateur `x == y`
#  - leur **non-égalité** avec l'opérateur `x != y`
#  - le **supérieur ou égal** avec l'opérateur `x >= y`
#  - le **plus petit ou égal** avec l'opérateur `x <= y`
#  - la **stricte supériorité** avec l'opérateur `x > y`
#  - la **stricte infériorité** avec l'opérateur `x < y`
#
# Dans tous les cas, ces tests ne peuvent valoir que True ou False ; ce sont des **booléens**.

# %% [markdown]
# *Remarques :*
# - Les tests d'égalité et de non égalité marchent aussi avec des chaîne de caractères ou des booléens.
# - Ils sont par contre à éviter avec des nombres flottants (nombres à virgules) car les erreurs d'arrondis peuvent rendrent différents des nombres qui devraient être égaux (voir IV.1).

# %% [markdown]
# **Q10. D'après vous que vaut l'expression `3*7%3 == 0` ? Après y avoir réfléchi, faire afficher la valeur de cette expression dans python et comparer à celle de `3*(7%3) == 0`. Que peut-on en déduire sur la priorité des opérateurs * et % ?**

# %%
# Question 10

# %% [markdown]
# ### V.2 La structure conditionnelle
# En python, une structure conditionnelle s'écrit en toute généralité de la façon suivante :
# > ``` python
# if test == True :
#     instruction1
# else :
#     instruction2
# ```
#
# Cela signifie que `instruction1` sera exécutée si le résultat du test est vrai et que sinon, c'est l'`instruction2` qui sera exécutée.

# %% [markdown]
# Comme la véracité du test est la condition par défaut pour exécuter la première instruction, le code précédent est complétement équivalent au code suivant :
# > ``` python
# if test :
#     instruction1
# else :
#     instruction2
# ```
#
# **<span style="color:red;">IMPORTANT :</span>** Remarquez la présence du caractère ":" à la fin des lignes commençant par `if` et `else`, ainsi que le décalage, appelé **indentation**, des lignes qui suivent ce caractère. Cela peut sembler anodin mais sans cela, le programme ne fonctionnera pas, ou pire, il fonctionnera mal !

# %% [markdown]
# *Remarques :*
# - La présence du `else` n'est pas obligatoire.
# - On peut tout à fait exécuter l'`instruction1` si le résultat du test est faux en mettant comme condition `test == False` ou `test != True` (la première expression est conseillée).
# - On peut aussi combiner plusieurs tests simultanément avec les opérateurs logiques `and`, `or`et `not` ("et", "ou" et "non"). Par exemple, l'expression `(test1 and test2) == true` n'est vraie que si test1 et test2 sont vrais simultanément.

# %% [markdown]
# **Q11. Avec les lignes de code suivantes, préciser quelles doivent être les valeurs (True ou False ou n'importe) de test1 et test2 pour que chacune des 5 instructions soient exécutées. Pour cela modifier le tableau réponse de la question 11 ci-dessous.**
# > ```python
# if test1 == True:
#     instruction1
#     if test2 == False:
#         instruction2
#     else:
#         instruction3
# else:
#     instruction4
# instruction5
# ```

# %% [markdown]
# *\# Question 11*
#
# |Instruction |test1|test2|
# |    :-:     | :-: | :-: |
# |instruction1|True |True |
# |instruction2|True |True |
# |instruction3|True |True |
# |instruction4|True |True |
# |instruction5|True |True |

# %% [markdown]
# ## VI. Les structures itératives (boucles)
# Une structure itérative permet de **répéter une instruction ou un bloc d'instructions un nombre entier de fois**. Ce nombre de répétition peut être fixé à l'avance (boucle `for`) ou bien il peut dépendre de la réalisation d'une condition (boucle `while`)

# %% [markdown]
# ### VI.1 La boucle for
# En python, les façons les plus courantes d'écrire une boucle `for` sont :
# > ```python
# \# i varie de 0 à 9 par pas de 1 ==> 10 exécutions des instructions
# for i in range(10):
#     instructions
# ```
#
# > ```python
# \# i varie de 1 à 9 par pas de 1 ==> 9 exécutions des instructions
# for i in range(1,10):
#     instructions
# ```

# %% [markdown]
# > ```python
# \# i varie de 0 à 9 par pas de 2 ==> 5 exécutions des instructions
# for i in range(0,10,2):
#     instructions
# ```
#
# > ```python
# \# i varie de 10 à 1 par pas de -1 ==> 10 exécutions des instructions
# for i in range(10,0,-1):
#     instructions
# ```

# %% [markdown]
# *Remarques :*
# - Comme pour les structures conditionnelles, la ligne qui commence par `for` finit par un ":" et la suivante est indentée.
# - En python, les lignes commençant par le caractère "#" ne sont pas interprétées, ce sont des **lignes de commentaires**.
# - Cette syntaxe utilise la fonction `range(debut, fin, pas)` qui renvoie en réalité une liste d'entier dont la première valeur est égale à `debut` et les suivantes sont incrémentées de `pas` en s'arrêtant juste avant d'atteindre ou de dépasser `fin`.
# - Par définition, une boucle for ne peut pas être une boucle infinie mais par contre, elle peut très bien ne jamais exécuter les instructions qu'elle contient.

# %% [markdown]
# - On peut parcourir une chaine de caractères avec une boucle for avec le code suivant :
#
# >``` python
# \# déclaration de la variable maphrase
# maphrase='Ceci est une chaîne de caractères.'
# \# pour chaque valeur de l'indice i dans l’intervalle [0,len(maphrase)-1]
# for i in range(len(maphrase)):
#     print(maphrase[i])
# ```

# %% [markdown]
# - Ou, mieux encore, avec :
#
# >``` python
# \# déclaration de la variable maphrase
# maphrase='Ceci est une chaîne de caractères.'
# \# pour chaque(for) caractère(car) dans(in) maphrase
# for car in maphrase:
#     print(car)
# ```

# %% [markdown]
# ### VI.2 La boucle while
# On peut par exemple écrire une boucle while de la façon suivante :
# > ``` python
# i=0
# pas=1
# while i<10 :
#     instructions
#     i=i+pas
# ```
#
# Tant que la condition i < 10 est vérifiée, les instructions contenues dans la boucle while sont exécutées.

# %% [markdown]
# Il faut faire très attention avec une boucle while car si la condition reste toujours vraie, on crée une **boucle infinie** de laquelle le programme ne pourra jamais sortir. Pour éviter cette boucle infinie, il faut s'assurer que les instructions contenues dans la boucle while sont à même de rendre fausse la condition de sortie de la boucle.
#
# Ici, i part de 0 et est incrémenté d'un `pas` qui vaut 1 à chaque tour de boucle. Cela continue tant que i est strictement inférieur à 10, la boucle est donc exécutée de i = 0 à i = 9, soit 10 fois. Cette boucle while est finalement équivalente à une boucle for i in range(10).

# %% [markdown]
# **Q12. Pour chacun des 3 programmes ci-dessous, essayer de prévoir ce que vaudra x à la fin de la boucle puis le vérifier en exécutant ces programmes.**
#
# > ``` python
# \#pgm1
# x = 0
# for i in range(5):
#     x = x + i
# \#pgm2
# x = 20
# for i in range(1,6):
#     x = x - i
# \#pgm3
# x = 1
# i=0
# while i < 1:
#     x = x + 1
#     i = i + 0.2
# ```

# %%
# Question 12

# %% [markdown]
# ### VI.3 Exemples
# - #### Compter les lettres
# Le programme ci-dessous compte le nombre de "e" présents dans la chaine de caractères 'Ceci est une chaine de caractères.'.
# > ```python
# maphrase = "Ceci est une chaîne de caractères."
# compteur=0
# for car in maphrase:
#     if car == 'e':
#         compteur=compteur+1
# print(compteur)
# ```

# %% [markdown]
# **Q13. Modifier ce programme pour qu'il compte également les "e" accentués puis pour qu'il compte toutes les voyelles, accentuées ou non.**
#
# *Remarque :* Il est préférable de tester le programme sur plusieurs phrases pour vérifier qu'il fonctionne correctement.

# %%
# Question 13

# %% [markdown]
# **Q14. Écrire un programme qui demande à l’utilisateur de rentrer un texte, puis qui affiche le pourcentage de "e" contenu dans le texte.**

# %%
# Question 14

# %% [markdown]
# - #### Le jeu du nombre mystère
# Le principe est simple, l’ordinateur choisit aléatoirement un entier compris entre 1 et 100, et l’utilisateur doit le trouver.
# Nous aurons besoin de la bibliothèque `random` pour utiliser la fonction `randint(a,b)` qui renvoie un nombre entier aléatoire entre a et b compris.
# Dans cet algorithme, on initialise une variable `nombre_a_tester` à 0, puis, tant que le nombre n'est pas trouvé, on invite l’utilisateur à entrer un nombre et on lui indique si le nombre cherché est plus grand ou plus petit.

# %% [markdown]
# Voilà le programme:
# > ```python
# from random import *
# nombre_a_trouver = randint(1,100)
# nombre_a_tester = 0
# while nombre_a_tester != nombre_a_trouver:
#     nombre_a_tester = int(input("veuillez entrer un entier entre 1 et 100 : "))
#     if nombre_a_tester > nombre_a_trouver :
#         print("C’est moins !")
#     if nombre_a_tester < nombre_a_trouver :
#         print("C’est plus !")
# print("Bravo ! Vous avez trouvé :",nombre_a_tester)
# ```

# %% [markdown]
# **Q15. Modifier le programme pour qu'il affiche aussi le nombre d'essais dont a eu besoin l'utilisateur pour gagner.**

# %%
# Question 15

# %% [markdown]
# **Q16. Que fait le programme suivant ?**
# >``` python
# from random import *
# lettres = "abcdefghijklmnopqrstuvwxyz"
# lettre_a_trouver = lettres[randint(0,len(lettres)-1)]
# lettre_a_tester = "0"
# compteur=0
# while lettre_a_tester != lettre_a_trouver :
#     lettre_a_tester = input("veuillez entrer une lettre en minuscule(non accentuée).")
#     compteur=compteur+1
#     if lettre_a_tester > lettre_a_trouver :
#         print("C’est avant !")
#     if lettre_a_tester < lettre_a_trouver :
#         print("C’est après !")
# print("Bravo ! Vous avez trouvé ",lettre_a_tester, " en " , compteur ,
# " essais.")
# ```

# %% [markdown]
# \# Question 16

# %% [markdown]
# ## VII. Les fonctions
# Une fonction est une sorte de raccourci vers un morceau de code qui a une tâche bien précise

# %% [markdown]
# ### VII.1 Déclaration d'une fonction
#
# En général, la fonction prend des **variables en entrée**, on les appelle les **paramètres** de la fonction et **renvoie un résultat**. On parle souvent de **procédure** pour les fonctions qui **ne renvoient pas de résultat** (elle modifie seulement les paramètres ou elle affiche quelque chose par exemple).
#
# L'intérêt d'une fonction est à la fois de **rendre plus lisible un programme** en le découpant en tâches simples réalisées par des fonctions aux noms explicites et de le simplifier en **évitant de recopier plusieurs fois des morceaux de codes presques identiques**.
#
# Une fonction peut être sauvegardée dans un fichier séparé du programme principal et appelée par ce dernier.

# %% [markdown]
# En python, une fonction est définie par l'instruction suivante :
# `def mafonction(parametre1, parametre2, ...):`
#
# C'est l'instruction `return` qui permet de préciser ce que renvoie la fonction.
#
# Quelques exemples de fonction :
# >``` python
# \# fonction avec 1 paramètre et un retour
# def f(x) :
#     return x**2+1
# \# on appelle la fonction par son nom, ici 5 fois
# for i in range(5) :
#     print(f(i))
# ```

# %% [markdown]
# >``` python
# \# fonction sans paramètres et sans retour
# def mafonction() :
#     for i in range(5) :
#     print(i*’*’) \# On appelle la fonction
# mafonction()
# ```
#
# >``` python
# \# fonction avec 2 paramètres et un retour
# def max(a,b) :
#     if a >= b :
#         return a
#     else :
#         return b
# print(max(25,13))
# ```

# %% [markdown]
# **Q.17 Prévoir puis vérifier ce que renvoie l'instruction `print(max(2,7),max(max(54,10),58))`.**

# %%
# Question 17

# %% [markdown]
# ### VII.2 Spécification d'une fonction
# Pour bien faire, toute fonction se doit d’être **spécifiée**, c'est-à-dire d'être livrée avec son **mode d'emploi**. Pour cela, il suffit d’écrire en début de fonction le type des paramètres d’entrées et les conditions sur
# ces paramètres, ce que fait la fonction et enfin le type de retour; le tout entre des triples guillemets.
#
# Par exemple pour notre fonction `max(a,b)` précédente cela pourrait donner :
# >```python
# def max(a,b):
# """ a est un entier, b est un entier. Compare les valeurs de a et b et renvoie le plus grand des 2."""
# if a >= b :
#     return a
# else :
#     return b
# ```

# %% [markdown]
# L’instruction `help(max)` affichera alors les spécifications de la fonction pour permettre à l'utilisateur de savoir comment l'utiliser :
#
# ```Help on function max in module __main__:
# max(a, b)
#     a est un entier, b est un entier. Compare les valeurs de a et b et renvoie le plus grand des 2.```

# %% [markdown]
# **Q.18 Afficher l'aide de la fonction `print`. Que signifie le fait que la valeur par défaut du paramètre `end` est '\n'? Tester le paramètre `sep` et décrire son utilisation.**

# %%
# Question 18

# %% [markdown]
# ***
# **Q.19 Ecrire les specifications des 3 programmes suivants :**
# >``` python
# def table_mult(a):
#     for i in range(11):
#         print(a, " x ", i, " = ", a*i)
# ```

# %% [markdown]
# >``` python
# def est_premier(n):
#     if n==2:
#         return True
#     if n%2 == 0 or n == 1:
#         return False
#     for i in range(3,n,2):
#         if n%i == 0:
#             return False
#     return True
# ```

# %% [markdown]
# >``` python
# def palindrome(mot):
#     l=len(mot)
#     for i in range(l):
#         if mot[i] != mot[l-i-1]:
#             return False
#         else:
#             return True
# ```

# %%
# Question 19

# %% [markdown]
# ## VIII. Exercices
#
# ### Exercice 1
# *Écrire une fonction `inverse(mot)` qui prend en paramètre un mot et qui renvoie le mot écrit à l’envers.*
#
# Exemple : bonjour → roujonb

# %% [markdown]
# ### Exercice 2
# La distance de Hamming **entre deux mots de même longueur** est le nombre d’endroits où les lettres sont différentes.
#
# Par exemple, prenons les mots 'japon' et 'savon'. La première lettre de japon est différente de la première lettre de savon, les troisièmes aussi sont différentes. La distance de Hamming entre japon et savon vaut donc 2.
#
# *Écrire une fonction qui calcule la distance de Hamming entre deux mots entrés par l’utilisateur en majuscule.*

# %% [markdown]
# ### Exercice 3
# Le latin-cochon :
# On transforme un mot commençant par une consonne selon la recette suivante :
# * on déplace la première lettre à la fin du mot
# * on rajoute le suffixe UM
#
# Ainsi, par exemple, VITRE devient ITREVUM.
#
# *Écrire une fonction qui transforme un mot en majuscules donné en argument en latin-cochon.*

# %% [markdown]
# ### Exercice 4
# *Écrire une fonction qui affiche les diviseurs d’un entier.*
#
# Exemple : 126 → 1-2-3-6-7-9-14-18-21-42-63-126

# %% [markdown]
# ### Exercice 5
# Un nombre de Armstrong est un **entier positif égal à la somme des cubes de ses chiffres**.
#
# Exemple : 153 = 1 +125 +27
#
# *Écrire une fonction qui prend en paramètre un entier $n$ et qui retourne les nombres de Armstrong inférieur à $n$.*

# %% [markdown]
# ### Exercice 6
# La suite de Fibonacci est définie par $f_0 = 0$,
# $f_1 = 1$ et $f_{n+2} = f_{n+1} + f_n$.
#
# *Écrire une fonction qui prend en paramètre un entier $n$ et qui affiche les $n$ premiers termes de la suite de Fibonacci.*

# %%
# Exercices

# %% [markdown]
# ## Pour les plus rapides et/ou les plus motivé.e.s (souvent, c'est les mêmes !)
# Vous pouvez compléter ce TD en faisant le travail proposé [ici](https://isn-icn-ljm.pagesperso-orange.fr/Python/index.html).
