# %%
# Permet de tout executer au lancement du notebook + conserver le notebook actif pendant 2h
from IPython.display import Javascript
from masquer import *
Javascript("""
function repeter(){
IPython.notebook.kernel.execute("a=1");
}
// execute a = 1 en python toutes les 8 minutes pendant 2h
let timerId = setInterval(() => repeter(), 4800);
setTimeout(() => { clearInterval(timerId); alert('fin de cession'); }, 7200000);

// Supprimer la taille limite pour la sortie d'une cellule
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
};
IPython.notebook.kernel.execute("url = '" + window.location + "'");

// Exécuter toutes les cellule du notebook
    require(
        ['base/js/namespace', 'jquery'], 
        function(jupyter, $) {
            
                
                jupyter.actions.call('jupyter-notebook:run-all-cells-below');
                jupyter.actions.call('jupyter-notebook:save-notebook');
                Jupyter.actions.call('jupyter-notebook:hide-header')

        }
    );""")

# %% [markdown]
# # <span style="color:red;"><center>Le rang d'une page Web </center></span>

# %% [markdown]
# ## 1. Le principe du PageRanking
#
# En 1998, deux jeunes doctorants de l’université de Stanford, Larry Page et Sergey Brin (en collaboration avec Motwani et Wynograd) publiaient un article intitulé "The PageRank Citation Ranking: Bringing Order to the Web" présentant les résultats d’un nouvel algorithme permettant de classer les pages web selon leur popularité et montrant la précision de cet algorithme sur un nouveau moteur de recherche appelé ... Google !

# %% [markdown]
# Voilà une version simplifiée de cet algorithme :
# - On simule le comportement d’un internaute.
# - On démarre au hasard sur une page.
# - On suit de façon aléatoire un lien sur cette page.
# - Et ainsi de suite...
#
# On impose le fait que dans 15% des cas , l’utilisateur abandonne sa navigation pour repartir d’une page au hasard.
#
# Notre utilisateur va se balader de pages en pages, en faisant son petit tour du net. A chaque fois que l’utilisateur tombe sur une page donnée, cette page gagne un point. Et à la fin, la page ayant le plus de point est alors la page la plus populaire du réseau !

# %% [markdown]
# ## 2. Description d'un cas particulier
#
# Considérons 6 sites web : A, B, C, D, E, F ayant des liens hypertexte entre eux.
# - Le site A contient un lien vers les sites "B", "C" et "E" (3 liens sortants)
# - Le site B contient un lien vers le site "F" (1 lien sortant)
# - Le site C contient un lien vers les sites "A" et "E" (2 liens sortants)
# - Le site D contient un lien vers les sites "B" et "C" (2 liens sortants)
# - Le site E contient un lien vers les sites "A", "B", "C", "D" et "F" (5 liens sortants)
# - Le site F contient un lien vers le site "E" (1 lien sortant)
#
# Cela peut se modéliser à l’aide du graphe suivant :
# ![Graphe%20pageranking.png](attachment:Graphe%20pageranking.png)

# %% [markdown]
# **Questions :**
#
# - D’après vous quel est le site le plus populaire?
#
# *Votre réponse ici ...*
#
# - Classer à priori les sites par ordre de popularité.
#
# *Votre réponse ici ...*

# %% [markdown]
# ## 3. Structurer les données
#
# Nous allons voir que les dictionnaires sont particulièrement adaptés pour représenter les sites et leur liens.
#
# Commencons par stocker les noms de sites dans une liste :
# `Websites = ["A","B","C","D","E","F"]`

# %%
#liste des sites web
Websites = ["A","B","C","D","E","F"]

# %% [markdown]
# ### Tâche n°1 :
# Créer un dictionnaire Hypertext dont les clés sont les sites web et les valeurs la liste
# des sites vers lesquels ils ont un lien sortant.
#
# Exemple : `Hypertext["A"] = ["B","C","E"]`

# %%
# Tâche n°1 :

# %% [markdown]
# ### Tâche n°2 :
# Créer un dictionnaire Walk_number dont les clés sont les sites web et les valeurs, initialisées à 0, sont le nombre de fois où le site a été visité.
#
# Exemple : `Walk_number["A"] = 0.0`

# %%
#Tâche n°2 :

# %% [markdown]
# ## 4. L'algorithme de calcul
#
# Voici une description plus précise de l'algorithme que l'on souhaite implémenter :
# > import random
# >
# >i=0
# >
# >tant que i<1000
# >> On choisit au hasard un site –> x
# >>
# >> Tant qu’un nombre aléatoire est inférieur à 0.85
# >>> Le nombre de visite de x est incrémenté de 1
# >>>
# >>> x <– un lien hypertexte visitable choisi de façon aléatoire
# >>
# >> i=i+1
# >
# > On fait afficher les résultats

# %% [markdown]
# ## 5. Programmation en python
#
# ### Utilisation de la bibliothèque (on parle aussi de module) `random`:
#
# - L’instruction `random.random()` renvoie un nombre dans l’intervalle $[0,1[$.
# - L’instruction `x = random.choice(Websites)` permet de choisir au hasard un site et de le stocker dans `x`
# - L’instruction `x = random.choice(Hypertext[x])` permet de ...
#
# **Remarques sur l'importation de bibliothèques :**
# Il y a plusieurs manière d'importer une bibliothèque, selon qu'on veut l'importer en entier ou en partie et selon la syntaxe avec laquelle on souhaite l'utiliser.
# - `import random` importe toute la blibliothèque et les fonctions s'utilisent comme des méthodes du module random, par exemple `x=random.random()` pour tirer un nombre aléatoire dans `x`.
# - `from random import random` n'importe que la fonction random du module random et cette fonction s'utilise comme si elle avait été directement définie dans le programme en cours, `x=random()` par exemple.
# - `from random import *` importe toutes les fonctions du module random et ces fonctions s'utilisent là aussi comme si elles avaient été directement définies dans le programme en cours, `x=random()` par exemple.

# %% [markdown]
# ### Tâche n°3 :
# Traduire l'algorithme précédent en Python et donner le classement des sites web obtenus

# %%
# Tâche n°3 :
