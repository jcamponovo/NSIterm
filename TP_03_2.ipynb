# %% [markdown]
# # <span style="color:red;"><center>TP - Le Titanic </center></span>

# %% [markdown]
# ## 1. Contexte historique
#
# Le Titanic appareille de Southampton (Angleterre) le mercredi 10 avril à 12 h 15 .
#
# Six heures plus tard, à 18 h 15, il fait escale dans la rade de Cherbourg. Il y débarque 24 passagers et en embarque 274, amenés par les transbordeurs Nomadic et Traffic. Il appareille à 20 h 10.
#
# Le Titanic fait route vers l'Irlande. Il arrive à Queenstown (aujourdhui Cobh) le 11 avril à 11 h 30. Il débarque 7 passagers et en embarque 120. À 13 h 30, le paquebot appareille et entame sa traversée de l'Atlantique vers New York .
#
# Le 14 avril, à 23 h 40 (heure locale, GMT-3), il percute un iceberg au large de Terre-Neuve. Il sombre le 15 avril à 2 h 20, causant la mort de 1 524 personnes.
#
# (source wikimanche)
# ![titanic.png](attachment:titanic.png)

# %% [markdown]
# ## 2. Le fichier
#
# Le fichier [titanic.csv](https://github.com/JeromeBarthelemy/NSI1ere/blob/master/Files/titanic.csv) donne des **informations sur un certain nombre de passagers** du Titanic.
#
# Il s'agit d'un fichier de données *CSV* avec la virgule comme séparateur et la première ligne comme descripteurs.
#
# Ouvrez ce fichier avec Libre Office Calc et identifiez les descripteurs suivants (noms exacts) :
#
# * Classe ( il y avait 3 classes [voir ici](https://fr.wikipedia.org/wiki/Passagers_du_Titanic) )
#
# * Survivant
#
# * Lieu d'embarquement

# %% [markdown]
# ## 3. Un script

# %% [markdown]
# Le script ci-dessous, ouvre le fichier *titanic.csv* et stocke chaque ligne sous forme de dictionnaire (avec les descripteurs comme clés) dans une liste.

# %%
import csv
reader = csv.DictReader(open('Files/titanic.csv', 'r'))
titanic = []
for row in reader:
    titanic.append(dict(row))


print(len(titanic))
print(titanic[53])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0f54eea2e554> in <module>
#       1 import csv
# ----> 2 reader = csv.DictReader(open('Files/titanic.csv', 'r'))
#       3 titanic = []
#       4 for row in reader:
#       5     titanic.append(dict(row))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Files/titanic.csv'

# %% [markdown]
# ## Tâche 1 :
#
#
# Écrire un programme qui calcule le nombre de survivants.
#
# **Attention :**
#
# * La valeur de la clé 'Survived' est de type `string`.
#
# * Pour l'atteindre sa valeur, on peut utiliser l'instruction : `titanic[n° de ligne]['Survived']`

# %%
# Écrire le script ici

# %% [markdown]
# ## Tâche 2 :
# Écrire un programme qui affiche le pourcentage (arrondi à l'unité) de survivants pour chacune des classes.

# %%
# Écrire le script ici

# %% [markdown]
# ## Tâche 3  :
# Écrire un programme qui donne le nombre de survivants embarqués à Cherbourg.

# %%
# Écrire le script ici
